# %% [markdown]
# <H1>INSTRUCTIONS</H1>

# %% [markdown]
# In this ICA, you will build various text classification models and use them to classify sentences from 2016 presidential debates according to speaker.
#
# The ICA zip file contains three files train, dev and test. The files are one document per line, tokenized and lowercased, so you don't have to do any preprocessing. Each line has the format:
#
#
#    <font color="red"> <center>trump i fully understand .</center></font>
#
# where the first token is the speaker's name, and the remaining tokens are the words of the document.

# %% [markdown]
# <H2>Hands on programming with Text Classification</H2>

# %% [markdown]
# Naive Bayes Classifier with 51.5% accuracy is provided.
# Experiment with two new kinds of features.
# <ol type="a">
# <li>Extend the code provided to construct a bag of words to include an additional kind of feature besides words. You can try bigrams, prefixes, parts of speech, anything you like. Describe your new features. Report your new accuracy. Briefly write down your conclusions from this experiment.<b>(5 points)</b></li>
#     <li>Do the same thing for another kind of feature. Report your new accuracy. Briefly write down your conclusions from this experiment.<b>(5 points)</b></li>
# </ol>

# %%
import pandas as pd
import numpy as np
import nltk

# %%
##Load Training Data
train_x=[]
train_y=[]

# %%
with open('train.txt', 'r') as f:
   for line in f:
        temp=line.split(' ',1)
        train_x.append(temp[1])
        train_y.append(temp[0])

# %%
np.unique(train_y)
# Out:
# array(['bush', 'carson', 'chafee', 'christie', 'clinton', 'cruz',
#        'fiorina', 'huckabee', 'kasich', "o'malley", 'paul', 'perry',
#        'rubio', 'sanders', 'trump', 'walker', 'webb'], dtype='<U8')

# %%
len(np.unique(train_y))
# Out:
# 17

# %%
train_df = pd.DataFrame({'sentence':train_x, 'speaker':train_y})
train_df.head()
# Out:
#                                             sentence  speaker
# 0  no . i am very proud to be jewish , and being ...  sanders
# 1  well , that just wasn't that just wasn't the f...  clinton
# 2  thank you , anderson . thank you , cnn . and t...   chafee
# 3                . . . let us talk about issues . \n  sanders
# 4                thank you , bernie . thank you . \n  clinton

# %%
##Load test data
test_x=[]
test_y=[]

# %%
with open('test.txt', 'r') as f:
   for line in f:
        temp=line.split(' ',1)
        test_x.append(temp[1])
        test_y.append(temp[0])

# %%
test_df = pd.DataFrame({'sentence':test_x, 'speaker':test_y})
test_df.head()
# Out:
#                                             sentence  speaker
# 0  madam secretary , when he asked me to speak . ...  sanders
# 1  too many lives have been destroyed because peo...  sanders
# 2                          . . . well and i . . . \n  sanders
# 3  look , the secretary is right . this is a terr...  sanders
# 4  well , hillary clinton , and everybody else wh...  sanders

# %% [markdown]
# <H3>Train Naive Bayes Classifier with the data in "train.txt" file</H3>

# %%
#Count of documents per class
from collections import Counter
docs_per_class = Counter(train_df['speaker'])
docs_per_class
# Out:
# Counter({'sanders': 501,
#          'clinton': 455,
#          'chafee': 18,
#          "o'malley": 128,
#          'webb': 28,
#          'bush': 207,
#          'cruz': 273,
#          'trump': 637,
#          'christie': 81,
#          'rubio': 305,
#          'kasich': 162,
#          'fiorina': 90,
#          'paul': 94,
#          'carson': 104,
#          'huckabee': 41,
#          'walker': 31,
#          'perry': 1})

# %%
from sklearn.feature_extraction.text import CountVectorizer
vect = CountVectorizer()
X_train_dtm = vect.fit_transform(train_df.sentence)

# %%
#count of words for all speakers
vect.vocabulary_
# Out:
# {'ain': 442,
#  'acquiring': 290,
#  'nicaraguan': 5515,
#  'assess': 741,
#  'quarters': 6495,
#  'possess': 6166,
#  'recall': 6618,
#  'partly': 5878,
#  'panels': 5841,
#  'planes': 6062,
#  'neutrally': 5502,
#  'cover': 2033,
#  'confronted': 1834,
#  'normal': 5551,
#  'alcohol': 466,
#  'amwill': 549,
#  'parental': 5859,
#  'marketing': 5083,
#  'lost': 4954,
#  'referenced': 6684,
#  'alongside': 498,
#  'columbus': 1690,
#  'equate': 2981,
#  'mandated': 5044,
#  'triad': 8369,
#  'behaved': 967,
#  'ended': 2906,
#  'paris': 5863,
#  'mom': 5331,
#  'mocked': 5314,
#  'see': 7246,
#  'hacked': 3805,
#  'rumble': 7081,
#  'made': 4999,
#  'rattling': 6575,
#  'responded': 6899,
#  'coroner': 1983,
#  'akron': 460,
#  'heed': 3917,
#  'priority': 6290,
#  'requested': 6858,
#  'cousin': 2032,
#  'embracing': 2849,
#  'contradicts': 1928,
#  'yours': 9064,
#  'gulf': 3786,
#  'highly': 3953,
#  'figures': 3312,
#  'ethanol': 3016,
#  'specter': 7625,
#  'continuously': 1922,
#  'maximize': 5117,
#  'militarily': 5223,
#  'enduring': 2916,
#  'fresh': 3527,
#  'neil': 5487,
#  'mm': 5308,
#  'taylor': 8061,
#  'inherited': 4303,
#  'ongoing': 5665,
#  'militarize': 5226,
#  'differences': 2457,
#  'treat': 8357,
#  'spouse': 7664,
#  'horribly': 4026,
#  'rightly': 6999,
#  'reading': 6590,
#  'basic': 910,
#  'nervous': 5493,
#  'gut': 3791,
#  'prescription': 6238,
#  'response': 6904,
#  'privatize': 6299,
#  'physically': 6023,
#  'oldest': 5656,
#  'revitalizes': 6964,
#  'collaboration': 1669,
#  'windfall': 8946,
#  'wait': 8781,
#  'governor': 3691,
#  'transpired': 8345,
#  'imagine': 4135,
#  'infiltrated': 4286,
#  'chance': 1494,
#  'hardworking': 3853,
#  'cruz': 2112,
#  'crimea': 2070,
#  'late': 4732,
#  'miserably': 5272,
#  'it': 4501,
#  'hotly': 4045,
#  'spending': 7636,
#  'conversation': 1947,
#  'pardon': 5855,
#  'yoga': 9055,
#  'six': 7469,
#  'clarity': 1605,
#  'values': 8658,
#  'suspends': 7962,
#  'armed': 692,
#  'monsters': 5346,
#  'small': 7505,
#  'honorable': 4008,
#  'worker': 8995,
#  'los': 4946,
#  'beaten': 937,
#  'ball': 858,
#  'contempt': 1906,
#  'weren': 8896,
#  'tuesday': 8417,
#  'mister': 5295,
#  'pose': 6159,
#  'admiration': 341,
#  'paradigm': 5848,
#  'backseat': 841,
#  'recommendation': 6641,
#  'miriam': 5267,
#  'everything': 3043,
#  'mobility': 5312,
#  'currently': 2134,
#  'personnel': 5990,
#  'proves': 6419,
#  'curriculum': 2135,
#  'fiance': 3297,
#  'religions': 6784,
#  'grateful': 3723,
#  'suffered': 7888,
#  'homophobic': 4000,
#  'vehicle': 8669,
#  'milwaukee': 5239,
#  'generational': 3610,
#  'underground': 8483,
#  'speeches': 7631,
#  'families': 3214,
#  'second': 7226,
#  'jimmy': 4539,
#  'interests': 4395,
#  'indicator': 4259,
#  'witness': 8974,
#  'projections': 6359,
#  'truancy': 8394,
#  'tactical': 8005,
#  'discussed': 2533,
#  'upstate': 8609,
#  'expensing': 3117,
#  'memorial': 5170,
#  'damaged': 2158,
#  'facts': 3191,
#  'fronts': 3536,
#  'maximizes': 5118,
#  'purposes': 6462,
#  'spiraling': 7645,
#  'preparation': 6230,
#  'intrigue': 4422,
#  'securing': 7244,
#  'repeating': 6831,
#  'detour': 2412,
#  '258': 106,
#  'decimated': 2214,
#  'say': 7156,
#  'assume': 755,
#  'attribute': 781,
#  'tinkering': 8230,
#  'nothings': 5565,
#  'developed': 2423,
#  'bathed': 918,
#  'congress': 1842,
#  'parade': 5846,
#  'sunday': 7909,
#  'rate': 6566,
#  'planet': 6063,
#  'bomber': 1121,
#  'profligate': 6346,
#  'eventually': 3037,
#  'poorest': 6144,
#  'decreasing': 2230,
#  'suspicious': 7963,
#  'mine': 5245,
#  'genocide': 3617,
#  'situation': 7467,
#  'cartoon': 1411,
#  'em': 2830,
#  'playing': 6078,
#  'ransom': 6556,
#  'improve': 4187,
#  'sort': 7584,
#  'facilities': 3182,
#  'import': 4170,
#  'abortions': 227,
#  'bland': 1066,
#  'christianity': 1565,
#  'cpi': 2039,
#  'too': 8255,
#  'nukes': 5582,
#  'davids': 2178,
#  'revenues': 6952,
#  'pandering': 5839,
#  'implode': 4169,
#  'downsize': 2670,
#  'marines': 5079,
#  'propagandist': 6379,
#  'diligence': 2468,
#  'immokalee': 4149,
#  'perseverance': 5983,
#  'need': 5468,
#  'accurate': 276,
#  'phones': 6017,
#  'returning': 6947,
#  'ptsd': 6434,
#  'pinnacle': 6043,
#  'kate': 4611,
#  'eastern': 2750,
#  'altered': 503,
#  'watches': 8837,
#  'flames': 3375,
#  'four': 3496,
#  'voices': 8755,
#  'captured': 1371,
#  'keeps': 4621,
#  'complain': 1763,
#  'hole': 3991,
#  'devalue': 2416,
#  'petulant': 6001,
#  'embarrassed': 2837,
#  'protections': 6409,
#  'machines': 4992,
#  'occupying': 5619,
#  'foothold': 3437,
#  'extending': 3158,
#  'classifying': 1614,
#  'chances': 1495,
#  'compliance': 1773,
#  'tirelessly': 8235,
#  'been': 951,
#  'latino': 4735,
#  'vigilance': 8715,
#  'virtually': 8735,
#  'sphere': 7640,
#  'broadsides': 1223,
#  'connections': 1853,
#  'everytime': 3044,
#  'impacting': 4155,
#  'forced': 3444,
#  'claims': 1600,
#  'chicken': 1540,
#  'militants': 5222,
#  'handout': 3830,
#  'members': 5168,
#  'start': 7707,
#  'happened': 3839,
#  'smiling': 7513,
#  'urging': 8617,
#  'isolated': 4489,
#  'ending': 2907,
#  'secretariat': 7231,
#  'paychecks': 5923,
#  'relative': 6768,
#  'encourage': 2894,
#  'anytime': 604,
#  'predominantly': 6217,
#  'actively': 300,
#  'courses': 2027,
#  'agreement': 427,
#  'include': 4220,
#  'naturalization': 5453,
#  'artificially': 716,
#  'external': 3161,
#  'depravity': 2347,
#  'preys': 6269,
#  'brilliant': 1210,
#  'entirely': 2963,
#  'diminish': 2470,
#  'muslim': 5416,
#  'escalation': 2999,
#  'arrival': 703,
#  'walk': 8791,
#  'stops': 7772,
#  'get': 3628,
#  'uncle': 8472,
#  'staffers': 7683,
#  'appointees': 640,
#  'rally': 6538,
#  'arrested': 701,
#  'warming': 8813,
#  'briefings': 1204,
#  'border': 1139,
#  'part': 5866,
#  'upset': 8605,
#  'proximity': 6431,
#  'portability': 6152,
#  'tuition': 8419,
#  'rebuild': 6614,
#  'owner': 5807,
#  'addressing': 325,
#  'conducive': 1813,
#  'harder': 3848,
#  'activity': 304,
#  '2nd': 113,
#  'criticized': 2086,
#  'impune': 4191,
#  'airbus': 445,
#  'fomenting': 3428,
#  'responsible': 6908,
#  'israelis': 4494,
#  'minorities': 5255,
#  'explains': 3134,
#  '2004': 78,
#  'taunt': 8052,
#  'laser': 4728,
#  'superstar': 7917,
#  'restored': 6913,
#  '11': 11,
#  'kabul': 4603,
#  'lids': 4848,
#  'kosovo': 4682,
#  'different': 2458,
#  'aggressive': 417,
#  'vendor': 8671,
#  'nine': 5528,
#  'quietly': 6507,
#  'bringing': 1213,
#  'bilateral': 1041,
#  'empathize': 2866,
#  'street': 7797,
#  'commentators': 1716,
#  'waited': 8782,
#  'agrees': 429,
#  'held': 3921,
#  'spender': 7635,
#  'case': 1415,
#  'gosh': 3679,
#  'grows': 3764,
#  'undertaking': 8502,
#  'financial': 3329,
#  'silent': 7438,
#  'advocate': 376,
#  'sympathetic': 7985,
#  'expenditures': 3114,
#  'markets': 5085,
#  'hemisphere': 3930,
#  'disrupt': 2576,
#  'supervision': 7918,
#  'victories': 8705,
#  'straighten': 7779,
#  'rico': 6987,
#  'graduated': 3702,
#  'educating': 2773,
#  'dog': 2631,
#  'exchange': 3070,
#  'crash': 2046,
#  'apologizing': 615,
#  'cheeks': 1531,
#  'refused': 6708,
#  'obstruction': 5609,
#  'overdose': 5779,
#  'men': 5174,
#  'gravity': 3727,
#  'enjoyed': 2940,
#  'nowhere': 5578,
#  'traditions': 8311,
#  'lonnie': 4935,
#  'medical': 5151,
#  'aren': 679,
#  'recession': 6628,
#  'overwhelm': 5800,
#  'devastating': 2420,
#  'exploit': 3138,
#  'devastate': 2418,
#  'rightful': 6998,
#  'celebrating': 1451,
#  'shelters': 7359,
#  'exercise': 3090,
#  'fallen': 3209,
#  'elite': 2823,
#  'pesh': 5994,
#  'killer': 4644,
#  'govern': 3686,
#  'theresa': 8160,
#  'welcome': 8885,
#  'horror': 4030,
#  'ounce': 5739,
#  'collecting': 1681,
#  'avenue': 811,
#  'love': 4961,
#  'extremism': 3168,
#  'apprehension': 648,
#  'object': 5598,
#  'precautions': 6206,
#  'actually': 308,
#  'memo': 5169,
#  'data': 2170,
#  'typically': 8449,
#  'tropical': 8389,
#  'korean': 4680,
#  'mechanisms': 5145,
#  'cap': 1359,
#  'offensive': 5632,
#  'abortionists': 226,
#  'several': 7326,
#  '37': 130,
#  'convoluted': 1960,
#  'steal': 7740,
#  'yasser': 9040,
#  'accomplish': 264,
#  'override': 5786,
#  'airmen': 450,
#  'turn': 8430,
#  'difficulty': 2463,
#  'below': 993,
#  'top': 8259,
#  'beliefs': 981,
#  'arc': 668,
#  'kamatsu': 4604,
#  'victims': 8704,
#  'announcements': 580,
#  'feels': 3275,
#  'invest': 4434,
#  'outposts': 5755,
#  'significant': 7434,
#  'spent': 7638,
#  'conditioners': 1810,
#  'economics': 2760,
#  '65': 168,
#  'killers': 4645,
#  'blind': 1076,
#  'developments': 2429,
#  'indefinite': 4249,
#  'game': 3577,
#  'blowing': 1091,
#  'lone': 4928,
#  'paranoia': 5852,
#  'special': 7614,
#  'everyday': 3041,
#  'ban': 864,
#  'resting': 6911,
#  'wayand': 8848,
#  'zero': 9070,
#  'equivalent': 2987,
#  'deal': 2186,
#  'passed': 5886,
#  'cybersecurity': 2147,
#  'armies': 693,
#  'egg': 2786,
#  'materiel': 5110,
#  'boot': 1137,
#  'mentally': 5177,
#  'city': 1590,
#  'safeguards': 7104,
#  'chanting': 1502,
#  'thoughtful': 8181,
#  'hassan': 3867,
#  'solar': 7544,
#  'downing': 2669,
#  'ops': 5703,
#  'take': 8010,
#  'johnkasich': 4547,
#  'producer': 6327,
#  'dedicated': 2232,
#  'screwed': 7204,
#  'sewer': 7328,
#  'amtrak': 546,
#  'space': 7603,
#  'encrypted': 2898,
#  'transcript': 8329,
#  'lesser': 4812,
#  'enrollees': 2947,
#  'stewardship': 7752,
#  'agitator': 420,
#  'welcomes': 8887,
#  'viruses': 8738,
#  'easiest': 2746,
#  'pacific': 5814,
#  'complicated': 1774,
#  'voting': 8768,
#  'advocated': 377,
#  'disproportionate': 2568,
#  'unrelated': 8575,
#  'practical': 6192,
#  'likes': 4866,
#  'threat': 8185,
#  'skeptic': 7476,
#  'mitch': 5301,
#  'tester': 8125,
#  'officials': 5643,
#  'historic': 3974,
#  'meaning': 5133,
#  'hanging': 3834,
#  'board': 1098,
#  'direct': 2479,
#  'stuff': 7838,
#  'dismantle': 2556,
#  'pitched': 6050,
#  'regain': 6712,
#  'determining': 2407,
#  'furthermore': 3563,
#  'graduation': 3704,
#  'brings': 1214,
#  'insulting': 4362,
#  'turkish': 8427,
#  'defenses': 2254,
#  'divert': 2603,
#  'copying': 1977,
#  'charleston': 1516,
#  'absentee': 233,
#  'marched': 5068,
#  '16': 27,
#  'racial': 6515,
#  '1981': 62,
#  'blinds': 1079,
#  'snake': 7522,
#  'militaristic': 5224,
#  'characterize': 1508,
#  'crumbling': 2107,
#  'italian': 4502,
#  'favored': 3248,
#  'recovered': 6652,
#  'mention': 5178,
#  'not': 5561,
#  '42': 138,
#  'rammed': 6543,
#  'embassies': 2840,
#  'statistics': 7726,
#  '700': 176,
#  'innovators': 4319,
#  'took': 8256,
#  'losing': 4951,
#  'florists': 3399,
#  'aid': 434,
#  'perpetrators': 5979,
#  'puppet': 6454,
#  'disrupted': 2577,
#  'trillion': 8381,
#  'civics': 1591,
#  'articles': 714,
#  'pointsecond': 6108,
#  'warren': 8820,
#  'cessation': 1473,
#  'looking': 4938,
#  'bombardment': 1118,
#  'broker': 1226,
#  'concur': 1807,
#  'exceptional': 3065,
#  'somewhere': 7572,
#  'priebus': 6275,
#  'payment': 5926,
#  'confirming': 1827,
#  'suits': 7900,
#  'empower': 2878,
#  'inefficiencies': 4274,
#  '2050': 94,
#  'journalists': 4568,
#  'bounty': 1157,
#  'penalty': 5947,
#  'criticizing': 2087,
#  'youngest': 9061,
#  'isil': 4478,
#  'luck': 4976,
#  '15': 25,
#  'canadians': 1347,
#  'leaked': 4769,
#  'sued': 7885,
#  'acquiescing': 288,
#  'human': 4066,
#  'mark': 5080,
#  'manipulation': 5053,
#  'sends': 7276,
#  'yeah': 9042,
#  'revive': 6965,
#  'arbitrary': 667,
#  'scores': 7189,
#  'hearing': 3899,
#  'aft': 400,
#  'rite': 7019,
#  'dorm': 2658,
#  'podium': 6102,
#  'capture': 1370,
#  'discourtesy': 2522,
#  'upgrade': 8596,
#  'correctly': 1990,
#  'damn': 2160,
#  'deterred': 2408,
#  'incumbents': 4246,
#  'there': 8158,
#  'properly': 6382,
#  'addict': 315,
#  'hashed': 3865,
#  'crimes': 2071,
#  'describe': 2362,
#  'fans': 3223,
#  'literally': 4890,
#  'pain': 5826,
#  'skepticism': 7478,
#  'ages': 413,
#  'talks': 8022,
#  'cultural': 2118,
#  'fads': 3192,
#  'assad': 735,
#  'orderly': 5715,
#  'cozy': 2038,
#  'reasserted': 6609,
#  'older': 5655,
#  'handed': 3825,
#  '130': 22,
#  'multinational': 5401,
#  'walked': 8792,
#  'snowden': 7525,
#  'romney': 7046,
#  'boiling': 1112,
#  'balanced': 854,
#  'doesn': 2630,
#  'll': 4900,
#  'differently': 2460,
#  'latinos': 4736,
#  'virginia': 8733,
#  'he': 3882,
#  'embrace': 2847,
#  'nafta': 5427,
#  '50s': 151,
#  'skilled': 7480,
#  'caucused': 1434,
#  '30': 114,
#  'thanks': 8140,
#  'outcome': 5745,
#  'neighbors': 5486,
#  'mayors': 5123,
#  '52s': 154,
#  'root': 7053,
#  'assure': 757,
#  'passionately': 5891,
#  'connected': 1849,
#  'tara': 8039,
#  'heartless': 3905,
#  'interplay': 4403,
#  'dark': 2167,
#  'sets': 7316,
#  'fighting': 3308,
#  'reverse': 6955,
#  'poured': 6181,
#  'do': 2619,
#  'testimony': 8129,
#  'governed': 3687,
#  'subsequent': 7854,
#  'fruit': 3537,
#  'subsidize': 7857,
#  'endangering': 2903,
#  'manipulate': 5051,
#  'exxonmobil': 3171,
#  'mail': 5009,
#  'contribute': 1931,
#  'eloquence': 2827,
#  'wolf': 8978,
#  'recipients': 6632,
#  'opponents': 5692,
#  'countrywide': 2019,
#  'affiliated': 387,
#  'cascading': 1414,
#  'dealing': 2188,
#  'memphis': 5173,
#  'appear': 623,
#  'perhaps': 5967,
#  'obliterate': 5604,
#  'chemicals': 1535,
#  'referred': 6686,
#  'incentivize': 4209,
#  'mirror': 5268,
#  'dysfunction': 2731,
#  'staying': 7733,
#  'establish': 3009,
#  'desperate': 2377,
#  'infected': 4283,
#  'lethal': 4817,
#  'prevailed': 6261,
#  'partial': 5867,
#  'expects': 3109,
#  'origin': 5728,
#  'vote': 8763,
#  'inaudible': 4198,
#  'messages': 5193,
#  'hostages': 4037,
#  'wrong': 9029,
#  'listening': 4887,
#  'panama': 5837,
#  'building': 1253,
#  'relying': 6790,
#  'regan': 6714,
#  'temperature': 8091,
#  'el': 2797,
#  'privilege': 6302,
#  'bigots': 1040,
#  'generosity': 3612,
#  'ashamed': 720,
#  'alcoholism': 468,
#  'self': 7264,
#  'knock': 4668,
#  'our': 5740,
#  'broadly': 1222,
#  'precious': 6209,
#  'time': 8223,
#  'mitigate': 5303,
#  'turnouts': 8434,
#  'communities': 1741,
#  'stand': 7695,
#  'environment': 2972,
#  'vets': 8691,
#  'imprisoning': 4186,
#  '97': 200,
#  'intensity': 4379,
#  'cdc': 1445,
#  'engagements': 2929,
#  'valley': 8654,
#  'nikki': 5526,
#  'liquid': 4882,
#  'cleanup': 1622,
#  'policies': 6119,
#  'ourselves': 5742,
#  'managed': 5036,
#  '1960s': 51,
#  'enemies': 2917,
#  'conservatives': 1867,
#  'unanswered': 8464,
#  'credit': 2066,
#  'fairness': 3204,
#  'wedge': 8875,
#  'tallahassee': 8024,
#  'telemundo': 8084,
#  'bluster': 1097,
#  'specifying': 7623,
#  'throats': 8200,
#  'jobs': 4543,
#  'files': 3316,
#  'differential': 2459,
#  'along': 497,
#  'belongs': 991,
#  'fantastic': 3225,
#  'sponsored': 7657,
#  'prayed': 6201,
#  'entails': 2951,
#  'conducting': 1816,
#  'distributed': 2592,
#  'barbaric': 886,
#  'martinomalley': 5093,
#  'lashing': 4729,
#  'pretenses': 6259,
#  'am': 514,
#  'embed': 2842,
#  'outraged': 5758,
#  'lucky': 4978,
#  'restructure': 6919,
#  'letting': 4821,
#  'streamlined': 7796,
#  'black': 1061,
#  'through': 8201,
#  'enter': 2953,
#  'esp': 3002,
#  'sarah': 7137,
#  '150': 26,
#  'continuum': 1923,
#  'credits': 2067,
#  'bankrupted': 873,
#  'restructuring': 6920,
#  'legacy': 4787,
#  'regard': 6715,
#  'courage': 2024,
#  '1990s': 68,
#  'james': 4512,
#  'about': 228,
#  'secretary': 7233,
#  'swamp': 7967,
#  'meantime': 5138,
#  'wing': 8948,
#  '2009': 83,
#  'frederick': 3515,
#  'basket': 914,
#  'province': 6427,
#  'birth': 1052,
#  'reforming': 6698,
#  'demographics': 2306,
#  'marrying': 5088,
#  'redundant': 6675,
#  'topline': 8263,
#  'african': 399,
#  'zones': 9076,
#  'areall': 677,
#  'sick': 7419,
#  '11th': 16,
#  'potential': 6177,
#  'disputed': 2572,
#  'abuser': 243,
#  'bank': 867,
#  'immediate': 4141,
#  'delay': 2278,
#  'wit': 8966,
#  'bet': 1015,
#  'evolution': 3050,
#  'quarantined': 6492,
#  'insecure': 4325,
#  'rove': 7070,
#  'state': 7716,
#  'security': 7245,
#  'leader': 4763,
#  'heal': 3890,
#  'implemented': 4165,
#  'warplanes': 8817,
#  'meanwhile': 5139,
#  '90s': 195,
#  'successfully': 7874,
#  'fire': 3345,
#  'iranian': 4465,
#  'should': 7395,
#  'terribly': 8113,
#  'restoring': 6914,
#  'invade': 4427,
#  'laughing': 4740,
#  'apologizes': 614,
#  'cooney': 1963,
#  'byron': 1311,
#  'decorations': 2227,
#  'developing': 2425,
#  'pointing': 6106,
#  'phase': 6006,
#  'judicial': 4581,
#  'backs': 840,
#  'deciding': 2211,
#  'furlough': 3561,
#  'conform': 1832,
#  'annie': 575,
#  'gather': 3594,
#  'tackle': 8001,
#  'life': 4852,
#  'slogans': 7501,
#  'dedicates': 2233,
#  'aliens': 473,
#  'revealed': 6950,
#  'honored': 4010,
#  'pushing': 6468,
#  'agonizing': 422,
#  'demonstrates': 2312,
#  'visceral': 8741,
#  'terrorism': 8118,
#  'reserve': 6871,
#  'move': 5383,
#  'foster': 3489,
#  'slot': 7502,
#  'religious': 6785,
#  'dislodge': 2555,
#  'hell': 3922,
#  'report': 6838,
#  'paraphrasing': 5854,
#  'retroactively': 6944,
#  'information': 4297,
#  'majority': 5020,
#  'resigned': 6880,
#  'petitioned': 5997,
#  'osama': 5734,
#  'equipment': 2984,
#  'murdered': 5407,
#  'hug': 4061,
#  'atomic': 765,
#  'population': 6149,
#  'millionaire': 5235,
#  'where': 8908,
#  'healed': 3891,
#  'extend': 3156,
#  'choices': 1555,
#  'dealings': 2189,
#  'democracy': 2301,
#  'modernize': 5324,
#  'unsustainable': 8583,
#  'bench': 997,
#  'thrive': 8196,
#  'player': 6076,
#  'incredible': 4240,
#  'reward': 6971,
#  'touching': 8278,
#  'manipulating': 5052,
#  'portend': 6154,
#  'crop': 2094,
#  'stabilize': 7674,
#  'sentiments': 7289,
#  'detonate': 2411,
#  'gains': 3571,
#  'guards': 3773,
#  'rides': 6991,
#  'trades': 8306,
#  'levers': 4827,
#  'antidote': 591,
#  'forgive': 3463,
#  'outlined': 5752,
#  'terrorists': 8120,
#  'altar': 502,
#  'heartly': 3907,
#  'reconciliation': 6645,
#  'marathon': 5066,
#  'las': 4727,
#  '2008': 82,
#  'fencing': 3286,
#  'waving': 8846,
#  'bid': 1031,
#  'parents': 5862,
#  'possibility': 6169,
#  'disability': 2488,
#  'grassroots': 3722,
#  'honor': 4007,
#  'biden': 1034,
#  'ame': 526,
#  'hung': 4079,
#  'predictable': 6216,
#  'suffering': 7889,
#  'leftist': 4785,
#  'launch': 4743,
#  'trail': 8318,
#  'proceeds': 6319,
#  'name': 5432,
#  'demonstrate': 2310,
#  'susan': 7956,
#  'kerry': 4629,
#  'dealers': 2187,
#  'praising': 6199,
#  'favorably': 3247,
#  'tradition': 8308,
#  'townhalls': 8293,
#  'releases': 6777,
#  'feckless': 3264,
#  'ceos': 1466,
#  'weakened': 8853,
#  'victim': 8702,
#  'many': 5062,
#  'rating': 6569,
#  'brigades': 1206,
#  'finally': 3326,
#  'bangladesh': 866,
#  'pledge': 6085,
#  'defrauding': 2268,
#  'customers': 2139,
#  'guns': 3790,
#  'flag': 3373,
#  'thrice': 8194,
#  'additional': 322,
#  'joe': 4544,
#  'delegates': 2280,
#  'raise': 6533,
#  'substantive': 7863,
#  'drag': 2682,
#  'cancel': 1349,
#  'horrified': 4028,
#  'marine': 5078,
#  'centered': 1459,
#  'departments': 2330,
#  'amazingly': 519,
#  'embassy': 2841,
#  'weaknesses': 8858,
#  'shortcut': 7390,
#  'charlie': 1517,
#  'earning': 2740,
#  'relation': 6764,
#  'opposed': 5696,
#  'videotape': 8709,
#  'quickly': 6504,
#  'groundwork': 3758,
#  'excruciating': 3077,
#  'refers': 6688,
#  'interfere': 4397,
#  'meaningless': 5135,
#  'disagreement': 2496,
#  'darn': 2168,
#  '20th': 96,
#  'thatcher': 8142,
#  'edward': 2776,
#  'pristine': 6294,
#  'doorstep': 2656,
#  'mailed': 5010,
#  'deere': 2243,
#  'talent': 8014,
#  'forth': 3478,
#  'joining': 4552,
#  'rescued': 6869,
#  'worried': 9003,
#  'spin': 7643,
#  'except': 3063,
#  'cheat': 1525,
#  'battleground': 926,
#  'next': 5512,
#  'florida': 3398,
#  'bloated': 1081,
#  'led': 4782,
#  'oppose': 5695,
#  'threshold': 8192,
#  'window': 8947,
#  'shape': 7343,
#  'testified': 8126,
#  'responders': 6901,
#  'struggling': 7830,
#  'unbelievable': 8468,
#  'decorated': 2226,
#  'painful': 5827,
#  'crowds': 2105,
#  'behalf': 965,
#  'registered': 6724,
#  'recklessness': 6635,
#  'reciprocal': 6633,
#  ...}

# %%
#Train Naive Bayes Classifier
#MultinomialNB has default smoothing factor of 1
from sklearn.naive_bayes import MultinomialNB
nb_clf = MultinomialNB().fit(X_train_dtm, train_df.speaker)

# %% [markdown]
# <H3>Test the developed naive bayes classifier with "test.txt" file</H3>

# %%
X_test_dtm = vect.transform(test_df.sentence)
predicted_speaker=nb_clf.predict(X_test_dtm)

# %%
from sklearn import metrics
metrics.accuracy_score(test_df.speaker, predicted_speaker)
# Out:
# 0.515

# %%
#Evaluate model
from sklearn import metrics
print(metrics.classification_report(test_df.speaker, predicted_speaker, target_names=test_df.speaker.unique()))
# Out:
#               precision    recall  f1-score   support
#
#      sanders       0.75      0.10      0.18        30
#      clinton       0.00      0.00      0.00        16
#     o'malley       0.00      0.00      0.00         2
#       chafee       0.00      0.00      0.00        12
#         webb       0.43      0.74      0.54        53
#     huckabee       0.79      0.65      0.71        34
#        trump       0.00      0.00      0.00        10
#         cruz       0.00      0.00      0.00         7
#         paul       0.79      0.35      0.49        31
#     christie       0.60      0.17      0.26        18
#        rubio       0.00      0.00      0.00         5
#      fiorina       0.52      0.54      0.53        41
#       kasich       0.51      0.69      0.59        64
#         bush       0.48      0.87      0.62        71
#       carson       0.00      0.00      0.00         3
#       walker       0.00      0.00      0.00         3
#
#     accuracy                           0.52       400
#    macro avg       0.30      0.26      0.24       400
# weighted avg       0.49      0.52      0.45       400
# c:\users\mohammed\appdata\local\programs\python\python35\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ## Problem 1

# %%
vect = CountVectorizer(tokenizer=nltk.word_tokenize,ngram_range=(1,3))
X_train_dtm = vect.fit_transform(train_df.sentence)
vect.vocabulary_
# Out:
# {'cutting social security': 71550,
#  'significant way in': 194429,
#  'laughing stock in': 133411,
#  'the japanese know': 214642,
#  'caught in': 61160,
#  'honest ,': 110652,
#  '. compared': 13680,
#  'in paris yesterday': 118163,
#  'have nukes': 105393,
#  'three words bush': 226639,
#  'with health .': 255282,
#  'top of every': 234249,
#  "'s visa overstays": 4090,
#  'a career': 20747,
#  "'s really doing": 3569,
#  ', to find': 11380,
#  'syria , parts': 203336,
#  'knows politicians': 132562,
#  'whatever they have': 250545,
#  'strategy for our': 200840,
#  'to say they': 231932,
#  'and start leading': 37935,
#  'every telephone': 84970,
#  'and marriage .': 36645,
#  'that and the': 207528,
#  'are talking about': 42688,
#  'many places .': 140770,
#  'and we stood': 39095,
#  "'d like": 186,
#  'legally in': 134880,
#  'nixon . he': 152205,
#  'deliver benefits': 73786,
#  'for middle': 91573,
#  'plots and these': 173728,
#  'privileges .': 177169,
#  'killing , i': 131589,
#  'seven million': 192790,
#  'people are tired': 170995,
#  'answer every single': 39775,
#  'a proliferation': 23216,
#  'people will get': 171899,
#  'the creation of': 212627,
#  'billionaire hedge fund': 53648,
#  "'d say a": 219,
#  'more special .': 145984,
#  'yours': 262462,
#  'i agree with': 112432,
#  'you that the': 261606,
#  'over this state': 168422,
#  'in explaining my': 117411,
#  'that is accurate': 208836,
#  'financial straits': 89165,
#  'have gotten it': 104952,
#  'on illegal': 162158,
#  'the 29': 211155,
#  'talked about people': 204589,
#  'exact amount': 85511,
#  'families would be': 87528,
#  'and bombs': 34479,
#  'administration regarding iraq': 27716,
#  'states act ,': 199804,
#  'mean that .': 142439,
#  'team . we': 205479,
#  ', if you': 8109,
#  'restore common': 185635,
#  'in critical': 117265,
#  'tonight is': 233880,
#  'militarize': 143703,
#  'have assets of': 104442,
#  'settle . that': 192738,
#  'economic barriers .': 80745,
#  'my comprehension': 147712,
#  "'s allowing": 2176,
#  'said that barack': 188294,
#  'year before they': 259365,
#  'members of the': 143022,
#  'rise of al': 186734,
#  'government gets big': 99376,
#  'where banks': 251126,
#  'of responsibility .': 159391,
#  'state is doing': 199555,
#  'or three times': 165152,
#  'schools work': 190136,
#  'on those promises': 162872,
#  'nervous': 151316,
#  'his billionaire': 109809,
#  'shenanigans with': 193305,
#  "does n't result": 78261,
#  'democracy in libya': 73880,
#  'more united': 146122,
#  'route through': 187224,
#  'anbar to': 33849,
#  'you bathe': 260455,
#  'very long': 240781,
#  'to pacs': 231164,
#  ', life expectancy': 8743,
#  'has absolutely': 103139,
#  'back fast': 46478,
#  'in this economy': 118991,
#  'person in this': 172419,
#  'over 36 year': 168200,
#  'quickly or': 180279,
#  'like my good': 136426,
#  "we 've gotten": 245857,
#  'wage jihad': 242301,
#  'the deals .': 212763,
#  'see double': 191124,
#  ', in life': 8176,
#  'about ben': 25061,
#  '11 was': 17593,
#  "'s always the": 2201,
#  'of damage .': 157567,
#  'doing their very': 78574,
#  'fall through': 87354,
#  'of this election': 160418,
#  'together 195': 233561,
#  '. close': 13653,
#  'saying oh ,': 189713,
#  'is because i': 123412,
#  'said in the': 188202,
#  'now threatening': 155720,
#  'sell american': 191634,
#  'really hard questions': 181889,
#  'doing business transactions': 78449,
#  'a safe country': 23565,
#  'series of articles': 192363,
#  'inspiration to many': 120793,
#  'attack somebody else': 45595,
#  'right approach': 186364,
#  'popular , in': 174910,
#  'seeing a doubling': 191352,
#  'where they get': 251338,
#  'it into the': 127600,
#  'financial institution': 89129,
#  'proxy conflict going': 179094,
#  'twice , and': 236638,
#  'other bodily fluids': 165527,
#  'debates where': 72728,
#  'kidding . they': 131341,
#  'it happen quickly': 127477,
#  'of my money': 158815,
#  'know , ,': 131940,
#  'illnesses , particularly': 115711,
#  "rand paul 's": 180898,
#  'donald was': 79048,
#  "'re getting .": 1355,
#  'their discourtesy ,': 219237,
#  'known as narcan': 132506,
#  'on street corners': 162517,
#  'his votes': 110167,
#  'sure . we': 202934,
#  'sixteen year old': 195043,
#  'level of cost': 135486,
#  ', industry': 8287,
#  'changing the systems': 62166,
#  'marco knows full': 140926,
#  'investigation . and': 122150,
#  ', our development': 9587,
#  'else goes': 82050,
#  ', i mentioned': 7979,
#  'fight . crosstalk': 88650,
#  "'m on both": 810,
#  ', she was': 10268,
#  'need in order': 150671,
#  'hear a': 107781,
#  'a solution of': 23795,
#  "'ya girls .": 4875,
#  'of different groups': 157647,
#  'government who are': 99584,
#  'asinine thinking': 44345,
#  'and individuals ,': 36175,
#  'did 106 town': 75212,
#  "have buyers '": 104625,
#  'child when my': 62669,
#  'was down': 243899,
#  'and beyond': 34438,
#  'think , actually': 223658,
#  'the right course': 217045,
#  "n't do what": 148758,
#  'they start hitting': 222925,
#  'you remove': 261409,
#  'plight of': 173719,
#  'americans out': 32909,
#  ', the news': 10951,
#  'aggressive without knowing': 29172,
#  'in a war': 116843,
#  'as was': 44225,
#  'go to aaa': 97661,
#  'our property': 167086,
#  'cost in': 68708,
#  'companies are not': 66075,
#  'those plans could': 226052,
#  'just hedge fund': 130248,
#  'a very hardline': 24343,
#  'everybody should .': 85171,
#  '5 billion .': 18977,
#  'safety legislation .': 187985,
#  'within my power': 256347,
#  'win again': 254537,
#  'absurd , and': 26204,
#  'country that does': 69719,
#  "'s a total": 2073,
#  'degree together': 73720,
#  'doing well .': 78612,
#  'a file at': 21591,
#  'politicians much better': 174600,
#  'played both in': 173583,
#  "'ll build our": 274,
#  'the country over': 212573,
#  'what washington ,': 250411,
#  'global scale': 97335,
#  'not radical': 154424,
#  'and a tragic': 34024,
#  'airplane , they': 29756,
#  'kate': 130894,
#  'way with terrorists': 245593,
#  'his grip': 109931,
#  'people as possible': 171016,
#  'so just by': 195770,
#  "it 's very": 126798,
#  'hearing numbers': 107968,
#  'is absolutely critical': 123178,
#  'this standard': 225566,
#  'and which': 39199,
#  "promising they 're": 178301,
#  'to afford those': 227847,
#  'in the wrong': 118905,
#  'classification . and': 63848,
#  'answer back against': 39767,
#  'a rosy': 23537,
#  'with thousands': 256160,
#  'claims': 63678,
#  'chicken': 62488,
#  'proving you': 179063,
#  "'s property": 3538,
#  'maybe the': 141705,
#  'but if they': 56916,
#  'been eliminated from': 50513,
#  'it came down': 127215,
#  'are protecting american': 42401,
#  'real work to': 181667,
#  'thousand years .': 226338,
#  'wealthy and the': 248307,
#  'to return': 231826,
#  'the futures': 213837,
#  'in stone': 118454,
#  'fault that fossil': 87954,
#  ', benghazi': 6172,
#  'in the first': 118706,
#  'external': 86578,
#  'overnight and everything': 168505,
#  'give people a': 96989,
#  'got two republicans': 99142,
#  'secretary carter is': 190604,
#  'the process .': 216567,
#  'agree with governor': 29366,
#  'addictions or problems': 27482,
#  'getting much': 96751,
#  'big desk': 53096,
#  'start , this': 199120,
#  'that the middle': 210193,
#  'walk': 242487,
#  'want to assess': 242911,
#  'robber robs': 186897,
#  'they either': 222369,
#  'commitment out': 65689,
#  'held ,': 108141,
#  'sending another carrier': 192079,
#  '. swing': 15874,
#  'clearly was helped': 64098,
#  'the ipad was': 214547,
#  'is falling': 123869,
#  'democrats in': 74099,
#  'recognizes how serious': 182645,
#  ', she lied': 10256,
#  "i 'm with": 112282,
#  'its original meaning': 128563,
#  'united states like': 238031,
#  'dreaming about going': 79836,
#  'dying and as': 80275,
#  'is revolutionary': 124908,
#  "'s called socialism": 2416,
#  'poorer neighborhoods': 174888,
#  'owner': 168804,
#  'to do things': 229231,
#  'his massive': 109985,
#  'there can': 221088,
#  'judges .': 129804,
#  'clear , local': 63946,
#  'in fixing america': 117461,
#  'admit that secretary': 27786,
#  'interdict the': 121310,
#  'friendlier . they': 93793,
#  'interesting question because': 121431,
#  'no question .': 152601,
#  'babies while they': 46344,
#  'hear the': 107837,
#  'that about': 207415,
#  'a transition .': 24209,
#  'but it will': 56971,
#  'border security and': 54488,
#  'side think i': 194243,
#  'pacifist ,': 168886,
#  'korea . when': 132626,
#  'inept ,': 120344,
#  'sister and brother': 194850,
#  "n't have gone": 149003,
#  'could move toward': 68935,
#  'opportunity for ,': 164349,
#  'fast as': 87861,
#  '80 years': 19429,
#  "n't see how": 149438,
#  'outside of': 168114,
#  'about issues .': 25374,
#  'down debt': 79526,
#  'public or': 179163,
#  'this is look': 225143,
#  'friends no longer': 93852,
#  'we should gradually': 247640,
#  'brother and son': 55564,
#  'it absolutely': 126985,
#  'goes by': 97856,
#  'to voter': 233128,
#  'children to': 62812,
#  'a bold and': 20617,
#  'their military .': 219499,
#  "we 'll go": 245686,
#  "n't worry about": 149754,
#  ', barack': 6049,
#  ', waste and': 11762,
#  'amazing thing': 31898,
#  'as , you': 43543,
#  'people can believe': 171080,
#  'hired a significant': 109697,
#  'borrowers .': 54599,
#  'those newspapers had': 226023,
#  'jeb , what': 128822,
#  'years ? which': 259554,
#  'in buying': 117100,
#  'save capitalism': 189012,
#  'and being left': 34414,
#  'out that under': 167851,
#  'i think while': 114297,
#  'in law and': 117801,
#  'country stronger and': 69706,
#  'should come back': 193673,
#  'hit very hard': 110338,
#  'story . soon': 200692,
#  'only send': 163993,
#  'just the hacking': 130560,
#  'govern': 99218,
#  'vote ,': 241906,
#  'reported in': 184582,
#  'agenda on': 29109,
#  'us surpluses': 239512,
#  'will do the': 253811,
#  'course . i': 69947,
#  'a party': 22870,
#  'be a security': 47878,
#  'things and i': 223451,
#  'iowa , and': 122372,
#  'means . even': 142489,
#  'economy . today': 80956,
#  'but other out': 57096,
#  'believe he is': 51817,
#  'friends here': 93843,
#  'of local': 158618,
#  'are realizing': 42429,
#  'to do every': 229201,
#  'love with': 138740,
#  'but once you': 57087,
#  'cautioned about a': 61247,
#  'this is easy': 225131,
#  'contradict the': 67978,
#  'from the trade': 94506,
#  'hard look at': 102900,
#  'who proposed massive': 252657,
#  ', greater respect': 7542,
#  'children and grandchildren': 62715,
#  'and took something': 38802,
#  'these videos and': 221788,
#  "clinton 's approach": 64181,
#  'thinking about my': 224281,
#  'because when their': 50115,
#  'situation that': 194972,
#  'justice system to': 130773,
#  'now helping to': 155511,
#  'two kids': 236766,
#  'you an answer': 260337,
#  '51 years': 19128,
#  'from gunmakers and': 94134,
#  'conditioners': 66754,
#  '. this whole': 16417,
#  'are having': 41859,
#  'they can affect': 222187,
#  'allies are': 30609,
#  'less incarceration': 135093,
#  'rate was': 181058,
#  'with without': 256267,
#  'presidency is': 175945,
#  'to a good': 227679,
#  'we are somehow': 246068,
#  'was irresponsible .': 244135,
#  'tough times .': 234553,
#  'problem , i': 177324,
#  'for hostages': 91423,
#  "'ve been downgraded": 4346,
#  'would let': 258693,
#  'the nominee .': 215669,
#  'felt , obviously': 88452,
#  'producers and': 177754,
#  'grandchildren , transform': 99902,
#  'enforcement . there': 83076,
#  'some jobs': 196707,
#  'that out there': 209507,
#  'i think new': 114257,
#  'notion . and': 155172,
#  'sensible person would': 192230,
#  '. trade is': 16510,
#  'government must': 99446,
#  'was no provisions': 244297,
#  'planning .': 173451,
#  'currency , what': 71258,
#  'have an entry': 104353,
#  'dnc quietly': 77040,
#  'website and': 248491,
#  '22 years ,': 18460,
#  'you raise and': 261364,
#  'be prosecuted': 48907,
#  'inappropriate , and': 119291,
#  'cap would': 60148,
#  'with women .': 256271,
#  'hope we': 110855,
#  'watching the early': 245165,
#  'of hers .': 158164,
#  'end up signing': 82707,
#  'have some remarkable': 105730,
#  'of the globe': 159952,
#  'matters in': 141497,
#  'clinton and carly': 64260,
#  'how would': 111610,
#  'the big internet': 211800,
#  'follow what you': 90694,
#  "'s say this": 3671,
#  'such as': 202003,
#  'advocated': 28035,
#  'tax anybody for': 204980,
#  'them to give': 220377,
#  ', tug': 11532,
#  'more progressive income': 145914,
#  'mine , one': 144223,
#  'dismantle': 76688,
#  'between eminent': 52830,
#  'and keep fighting': 36374,
#  'so narrow here': 195865,
#  'at and': 44983,
#  'it as much': 127116,
#  'got a corrupt': 98810,
#  'brings': 55427,
#  'her or': 108607,
#  'regime change would': 183460,
#  'malevolent force .': 140247,
#  'way of life': 245455,
#  'for itself .': 91498,
#  'stepped in': 200251,
#  'than american': 206615,
#  'better know': 52688,
#  'apartment and own': 40594,
#  'them lobbying congress': 220205,
#  'being part of': 51604,
#  'millions running around': 144155,
#  'second amendment': 190408,
#  'around to': 43432,
#  'coordinating efforts against': 68369,
#  'candidate .': 60031,
#  'the cayman islands': 212132,
#  '1960 , it': 17978,
#  ', 200 years': 4996,
#  'probably every special': 177248,
#  'the al': 211330,
#  'season and i': 190363,
#  'republicans , we': 184868,
#  'retirement , that': 185824,
#  'everybody on this': 85145,
#  'only one industry': 163918,
#  'immunity . let': 116063,
#  'theories or broad': 220843,
#  'hill . i': 109314,
#  'apology tour': 40652,
#  'radically changing the': 180578,
#  'and publicizing them': 37381,
#  'general election match': 95582,
#  'raise wages': 180688,
#  'for survivors': 91981,
#  'wanted to add': 243107,
#  'just crazy': 130141,
#  'another war': 39733,
#  'gulf nations': 101215,
#  'mother and': 146536,
#  'like isis ,': 136354,
#  'end corporate': 82597,
#  'rich ,': 186107,
#  'series': 192361,
#  "nation 's history": 150011,
#  'temperament ,': 205885,
#  'most other counties': 146397,
#  'a leadership': 22232,
#  'the 1930s ,': 211110,
#  'to deteriorate .': 229098,
#  'my colleague in': 147691,
#  'everything .': 85323,
#  'only by the': 163760,
#  'at its worst': 45130,
#  'zealots that': 262520,
#  'terrorism or': 206314,
#  'night , had': 152113,
#  'been willing': 50969,
#  'would have allowed': 258598,
#  'lost our': 138374,
#  'and people you': 37210,
#  'officials who i': 161300,
#  'sure they get': 203032,
#  'congress and working': 67062,
#  'where a': 251105,
#  'arbitrary': 41173,
#  ', absolutely incompetent': 5273,
#  'arrests had': 43463,
#  'ending the era': 82773,
#  'infrastructure to': 120576,
#  'heard this ,': 107923,
#  'beliefs . it': 51752,
#  'women drive': 256736,
#  'that lifts all': 209114,
#  'on millions of': 162327,
#  'jeb mentioned': 128859,
#  'the russians got': 217156,
#  ', they hate': 11214,
#  "'ll say one": 425,
#  'the large': 214778,
#  'great challenge': 100108,
#  'from controlling ,': 94053,
#  'you did .': 260660,
#  '? in': 19975,
#  'i disagree on': 112937,
#  'wrote the': 259213,
#  'any budget that': 39984,
#  'in most': 117941,
#  'a': 20268,
#  'committee chairman ,': 65759,
#  'universal healthcare': 238094,
#  'terms of jobs': 206090,
#  "'s employer who": 2599,
#  'it a public': 126974,
#  'and candy': 34574,
#  'one or two': 163405,
#  'terrible health care': 206155,
#  'because their': 49969,
#  'to some': 232180,
#  'as a means': 43596,
#  'foley was': 90592,
#  'they were invited': 223095,
#  'additional child tax': 27514,
#  'emboldens israel': 82206,
#  'correct here ,': 68573,
#  'our legislation an': 166772,
#  'about anything but': 25024,
#  'to create feedback': 228889,
#  'so the point': 196006,
#  'both to tell': 54795,
#  ', says the': 10171,
#  'vulnerable and': 242248,
#  'their taxes': 219760,
#  ', its': 8496,
#  'wealthy people make': 248323,
#  'be no turning': 48758,
#  'podiums are': 173797,
#  'only knows saddam': 163889,
#  'ago how': 29271,
#  'not getting any': 153809,
#  'is a county': 122955,
#  'i give you': 113127,
#  'child support with': 62656,
#  'speaking about': 197910,
#  'stupid trade .': 201720,
#  'it was advising': 128208,
#  'undermines the': 237360,
#  'are there good': 42757,
#  'put your finger': 179691,
#  'an economy if': 33387,
#  'obama was able': 156431,
#  'be exceptions': 48346,
#  'who invest': 252499,
#  'country will never': 69829,
#  'days of': 72179,
#  'minority and women': 144344,
#  'gaza . they': 95531,
#  ', feel': 7167,
#  'educate people ,': 81143,
#  'pressure without being': 176543,
#  'hate the term': 103943,
#  'choices and': 63126,
#  'have a retirement': 104203,
#  'others . and': 165860,
#  '. passing a': 15389,
#  'that unites': 210504,
#  'that , whether': 207254,
#  'growing jobs': 100926,
#  'congressional black caucus': 67163,
#  'and the other': 38366,
#  'the way i': 218672,
#  ', the other': 10970,
#  'to beat hillary': 228385,
#  'senator cruz': 191859,
#  'inspecting them': 120780,
#  ', but with': 6425,
#  'voted in': 242054,
#  'prevailed': 176621,
#  'believe in a': 51832,
#  'a phone': 22956,
#  'difficult for me': 75914,
#  'scrutinized ,': 190288,
#  'presidency i': 175943,
#  'saudis have': 188992,
#  'a tiny': 24158,
#  'now exists': 155448,
#  'my web': 148355,
#  'over 40': 168201,
#  'ashamed': 44311,
#  'you everybody .': 260743,
#  'the watch of': 218645,
#  'them with a': 220472,
#  'so that companies': 195962,
#  'scare tactics .': 189931,
#  'to five years': 229593,
#  'pacific region': 168882,
#  'outside of an': 168115,
#  'back around': 46446,
#  'know this': 132350,
#  "did n't work": 75449,
#  'world . you': 257816,
#  'given up .': 97123,
#  'vat tax ,': 240271,
#  'good enough lawyer': 98483,
#  'opportunity than our': 164375,
#  '100 0 in': 17441,
#  'beer summit': 50986,
#  'managed': 140357,
#  'even better than': 84199,
#  'the monetary': 215347,
#  'often are keeping': 161319,
#  'tactics do not': 203802,
#  'to not': 231022,
#  'a plan right': 22997,
#  'say my': 189431,
#  'to this question': 232884,
#  'new york for': 151859,
#  'everybody to understand': 85185,
#  'or later': 164908,
#  'armies of': 43230,
#  "'ll have": 346,
#  'gets the most': 96646,
#  'maybe he': 141656,
#  'their loved': 219487,
#  'madame secretary ,': 139057,
#  ', just again': 8565,
#  'you get ,': 260800,
#  'i love it': 113615,
#  'that new': 209345,
#  'moms ,': 144965,
#  'are surrounding': 42671,
#  'state were': 199666,
#  'pac , who': 168859,
#  'and a great': 33991,
#  '. that should': 15975,
#  'being conducted now': 51495,
#  'we go to': 246661,
#  'with persistent': 255654,
#  'na clean it': 149787,
#  'of jobs and': 158449,
#  ', then some': 11133,
#  'like to see': 136627,
#  'this chance': 224706,
#  '. spend a': 15838,
#  'trump . the': 235912,
#  'powell and close': 175359,
#  'be naturalized': 48734,
#  'there . what': 220964,
#  'to trust': 232978,
#  'those years ,': 226211,
#  'before it was': 51061,
#  'of god and': 158022,
#  'influence back': 120436,
#  'me from': 142065,
#  "hillary 's": 109317,
#  'majority position': 139543,
#  'record of working': 182780,
#  'difference with': 75722,
#  'oil , absolutely': 161469,
#  'bracket . and': 54920,
#  'that these people': 210296,
#  'the federal level': 213523,
#  'swamp': 203228,
#  'somebody over there': 196974,
#  'for themselves already': 92210,
#  'at the way': 45421,
#  'build their military': 55914,
#  '000 more': 17201,
#  'that state': 209982,
#  'other risks that': 165749,
#  'serious strategy': 192452,
#  "economy 's flat": 80917,
#  "'s in trouble": 2954,
#  'say that with': 189503,
#  ', justice scalia': 8587,
#  'bank': 47133,
#  'to present strength': 231325,
#  'fiance': 88585,
#  'currently the leader': 71313,
#  'for the nation': 92122,
#  'the vfw ,': 218503,
#  'in campaign contributions': 117120,
#  'against going': 28801,
#  'resolve the conflict': 185220,
#  'prior presidential': 176937,
#  "'m happy to": 679,
#  'a tough guy': 24172,
#  'to be really': 228290,
#  'be happening': 48477,
#  'came time after': 58879,
#  'reagan administration': 181435,
#  'for millions more': 91580,
#  'they have the': 222552,
#  'by lifting': 57958,
#  'apiece .': 40600,
#  'speech that i': 198166,
#  ', excellent ,': 7104,
#  'using the term': 239976,
#  'view , secretary': 241440,
#  'missile that': 144518,
#  'unified , and': 237805,
#  'really am .': 181758,
#  'pointing': 173945,
#  'with high income': 255294,
#  'black men are': 53880,
#  'way from': 245397,
#  'smell ,': 195381,
#  'furlough': 95050,
#  'raise a': 180622,
#  'there are 800': 221000,
#  'aliens': 29879,
#  'here or the': 108894,
#  'you think this': 261644,
#  'in government at': 117539,
#  'the show with': 217463,
#  'a request': 23457,
#  'truck . they': 235748,
#  'the constitution has': 212481,
#  ', having said': 7639,
#  'great idea to': 100213,
#  'many people over': 140757,
#  'former senators said': 92832,
#  'understand who we': 237546,
#  'and always has': 34167,
#  'marco .': 140898,
#  'has done': 103383,
#  'abuse , let': 26237,
#  'rotary wing aircraft': 187182,
#  'about it you': 25396,
#  'with polio': 255662,
#  'to our fiscal': 231114,
#  'which codified': 251566,
#  'is safe ,': 124945,
#  'wisconsin and': 254745,
#  '. . pointing': 12661,
#  'and not go': 36917,
#  "obama 's committed": 156154,
#  "'s france": 2727,
#  'women . but': 256699,
#  'for his life': 91414,
#  'community were': 66020,
#  'on for many': 162054,
#  'you take': 261563,
#  'radical group': 180495,
#  'affect the': 28089,
#  'of 505': 156828,
#  "' voting": 91,
#  'i loved ted': 113624,
#  'time . are': 227066,
#  'flat tax that': 90113,
#  'not an': 153299,
#  'will not pay': 254117,
#  'looked very carefully': 138048,
#  'card at the': 60343,
#  'and from students': 35481,
#  'and washington': 39002,
#  'negative ads and': 151072,
#  'twice , he': 236640,
#  'been prosecuted': 50757,
#  'ongoing relationships with': 163700,
#  'forgive': 92741,
#  'built the great': 56025,
#  'we lose that': 247121,
#  'able to apply': 24733,
#  'are not .': 42185,
#  'affordable healthcare': 28195,
#  'neil can': 151290,
#  'a violation ,': 24405,
#  'will require': 254224,
#  'both republicans': 54758,
#  'macho sending': 139045,
#  'to pass ,': 231182,
#  'every day ?': 84716,
#  'the politicians that': 216312,
#  'me that i': 142258,
#  'turn the page': 236494,
#  'and have them': 35684,
#  'of drugs': 157733,
#  'iraq , one': 122628,
#  'money , to': 145013,
#  'masses in chanting': 141314,
#  'them fight .': 220095,
#  "he 's stolen": 106604,
#  'when somebody': 250846,
#  'are not ,': 42184,
#  'worse off than': 258137,
#  'completely .': 66363,
#  'frankly have': 93472,
#  'government . the': 99273,
#  'street that destroys': 201069,
#  'but would': 57479,
#  'biggest problems': 53342,
#  'so nobody': 195868,
#  'actually continue': 27122,
#  'i , the': 112377,
#  'brought to new': 55664,
#  'we could arm': 246333,
#  'look at premiums': 137924,
#  'be much change': 48718,
#  'guns': 101321,
#  '; the iraqi': 19709,
#  'kerry senator rubio': 131223,
#  'principle of elevating': 176882,
#  'the lobbyists ,': 215039,
#  'drag': 79751,
#  'our economic system': 166389,
#  'will make .': 254050,
#  'raised money': 180732,
#  'jobs for our': 129364,
#  'a strong message': 23932,
#  'your head .': 262178,
#  'for each man': 91223,
#  'the gun industry': 214128,
#  'that anybody': 207545,
#  'tackle the cost': 203776,
#  'classified material .': 63862,
#  'are some of': 42590,
#  'these complex problems': 221461,
#  'borders and': 54533,
#  'ideas that i': 115003,
#  'her body with': 108533,
#  'is you look': 125767,
#  'politician right now': 174538,
#  'poor kids who': 174856,
#  'is found': 123912,
#  ', they earn': 11202,
#  'presidential candidate': 176462,
#  'one , and': 163112,
#  'much people': 147133,
#  'and their sons': 38506,
#  'said . that': 188083,
#  'giving someone': 97208,
#  'someone else ,': 197079,
#  'and your rights': 39425,
#  'do the kind': 77814,
#  'need a coalition': 150532,
#  'and boys and': 34489,
#  'in nato .': 117995,
#  'rescued': 185109,
#  'for office ,': 91674,
#  'a big way': 20546,
#  'cruz . i': 71087,
#  'he is generally': 106973,
#  '. eliminates the': 13815,
#  'some 100 million': 196566,
#  'even smaller': 84353,
#  'abysmally': 26284,
#  'is why isis': 125707,
#  'a low blow': 22408,
#  ', the taliban': 11055,
#  ', the home': 10886,
#  'budget committee chairman': 55771,
#  'i led': 113548,
#  'being covered': 51498,
#  'fix our roads': 89990,
#  'the senate': 217368,
#  'talked to some': 204610,
#  'run for office': 187436,
#  'to find terrorists': 229576,
#  'positive relations': 175115,
#  'the bloodiest ,': 211868,
#  'measure': 142613,
#  '. we reported': 16750,
#  'in their paycheck': 118933,
#  'not just on': 154036,
#  'the attack in': 211521,
#  'college affordable': 65002,
#  'to a long': 227691,
#  'wan': 242668,
#  'the standards': 217670,
#  'learned that the': 134365,
#  'point ,': 173800,
#  ', as somebody': 5961,
#  'win when people': 254594,
#  'many innocent people': 140656,
#  'that have been': 208508,
#  'ohio where we': 161466,
#  'their corner .': 219170,
#  'will replace justice': 254223,
#  'i mean by': 113654,
#  'about their': 25794,
#  'get the maximum': 96408,
#  'and in other': 36107,
#  'disadvantaged ever since': 76190,
#  'an out': 33756,
#  'every norm that': 84851,
#  "'re the greatest": 1807,
#  'because the intelligence': 49946,
#  'one candidate on': 163216,
#  'republican nominee': 184781,
#  'you want people': 261741,
#  ', and daughters': 5548,
#  'internet , you': 121572,
#  'the bureaucracy down': 212003,
#  'and better ,': 34433,
#  'judeo christian': 129778,
#  'it down .': 127329,
#  'cops on the': 68382,
#  'everything that she': 85394,
#  'are underinsured with': 42862,
#  'victims .': 241326,
#  'veterans committee': 241141,
#  'for governor .': 91346,
#  'talked to says': 204607,
#  'groups like isis': 100833,
#  'point , which': 173818,
#  'difficult to do': 75943,
#  "'s here": 2871,
#  'your person .': 262293,
#  'autistic': 46000,
#  'business flat': 56368,
#  'to 3 .': 227613,
#  'economy are': 80980,
#  ', not seen': 9319,
#  'exactly what he': 85569,
#  'grid to defend': 100623,
#  'looking well .': 138098,
#  'money and put': 145060,
#  'there . there': 220960,
#  'of people who': 159148,
#  'penetrate these': 170667,
#  'lottery': 138631,
#  'bailout in': 46970,
#  'right and right': 186361,
#  'business here': 56373,
#  'be no': 48751,
#  'as we could': 44235,
#  'bermuda and in': 52314,
#  'million individual': 144002,
#  'debated for 30': 72696,
#  'nominating somebody': 152854,
#  'spaces with a': 197827,
#  ', fiscal': 7197,
#  'answer they': 39823,
#  'geographically': 95786,
#  'attacked us in': 45659,
#  'succeeding on': 201900,
#  'america lost since': 32275,
#  'the internet better': 214523,
#  'team jersey ,': 205485,
#  'over a hundred': 168232,
#  'radical islamic terrorism': 180513,
#  'about 2': 24929,
#  'as it continues': 43876,
#  'she should': 193208,
#  'in less than': 117817,
#  'i jake': 113445,
#  "n't know ,": 149138,
#  'christians': 63261,
#  'together with law': 233670,
#  'realistic': 181676,
#  'adjustable ,': 27605,
#  "that 's real": 207144,
#  'now asking the': 155373,
#  'tree': 235352,
#  'brokered convention .': 55549,
#  'validation': 240124,
#  'elected he will': 81712,
#  'speculative , risky': 198133,
#  'they vigilant': 223025,
#  'that every water': 208237,
#  ...}

# %%
nb_clf = MultinomialNB().fit(X_train_dtm, train_df.speaker)
X_test_dtm = vect.transform(test_df.sentence)
predicted_speaker=nb_clf.predict(X_test_dtm)

# %%
metrics.accuracy_score(test_df.speaker, predicted_speaker)
# Out:
# 0.465

# %%
print(metrics.classification_report(test_df.speaker, predicted_speaker, target_names=test_df.speaker.unique()))
# Out:
#               precision    recall  f1-score   support
#
#      sanders       0.00      0.00      0.00        30
#      clinton       0.00      0.00      0.00        16
#     o'malley       0.00      0.00      0.00         2
#       chafee       0.00      0.00      0.00        12
#         webb       0.27      0.75      0.39        53
#     huckabee       0.88      0.44      0.59        34
#        trump       0.00      0.00      0.00        10
#         cruz       0.00      0.00      0.00         7
#         paul       0.50      0.03      0.06        31
#     christie       1.00      0.06      0.11        18
#        rubio       1.00      0.20      0.33         5
#      fiorina       0.65      0.37      0.47        41
#       kasich       0.61      0.80      0.69        64
#         bush       0.50      0.87      0.64        71
#       carson       0.00      0.00      0.00         3
#       walker       0.00      0.00      0.00         3
#
#     accuracy                           0.47       400
#    macro avg       0.34      0.22      0.21       400
# weighted avg       0.46      0.47      0.39       400
# c:\users\mohammed\appdata\local\programs\python\python35\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# I used unigram, bigram an trigram count as new features to the model. however the accuracy dicreases to 46%. However, if i use only bigram or trigram count the accuracy will be around 57%

# %% [markdown]
# ## Problem 2

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vect = TfidfVectorizer(tokenizer=nltk.word_tokenize)
X_train_dtm = vect.fit_transform(train_df.sentence)

# %%
vect.vocabulary_
# Out:
# {'possess': 6204,
#  'acquiring': 318,
#  'nicaraguan': 5548,
#  'assess': 768,
#  'quarters': 6534,
#  'recall': 6658,
#  'partly': 5916,
#  'panels': 5879,
#  'planes': 6100,
#  'neutrally': 5535,
#  'cover': 2061,
#  'confronted': 1863,
#  'normal': 5584,
#  'alcohol': 494,
#  'amwill': 577,
#  'parental': 5897,
#  'marketing': 5113,
#  'lost': 4984,
#  'referenced': 6724,
#  'alongside': 526,
#  'columbus': 1719,
#  'equate': 3007,
#  'mandated': 5074,
#  'triad': 8410,
#  'behaved': 995,
#  'ended': 2932,
#  'paris': 5901,
#  'mom': 5361,
#  'mocked': 5344,
#  'see': 7287,
#  'hacked': 3833,
#  'rumble': 7121,
#  'made': 5030,
#  'rattling': 6615,
#  'responded': 6939,
#  'coroner': 2012,
#  'akron': 488,
#  'heed': 3943,
#  'priority': 6328,
#  'requested': 6898,
#  'cousin': 2060,
#  'embracing': 2875,
#  'contradicts': 1957,
#  'yours': 9107,
#  'gulf': 3813,
#  'highly': 3979,
#  'figures': 3339,
#  'ethanol': 3042,
#  'specter': 7664,
#  'continuously': 1951,
#  'maximize': 5147,
#  'militarily': 5253,
#  'enduring': 2942,
#  'fresh': 3554,
#  'neil': 5520,
#  "let'slet'slet": 4847,
#  'mm': 5338,
#  'taylor': 8102,
#  'inherited': 4330,
#  'ongoing': 5702,
#  'militarize': 5256,
#  'differences': 2485,
#  'treat': 8398,
#  'spouse': 7703,
#  'horribly': 4052,
#  'rightly': 7039,
#  'reading': 6630,
#  'basic': 938,
#  'nervous': 5526,
#  'gut': 3818,
#  'prescription': 6276,
#  'response': 6944,
#  'privatize': 6337,
#  'physically': 6061,
#  'oldest': 5693,
#  'revitalizes': 7004,
#  'collaboration': 1698,
#  'windfall': 8987,
#  'na': 5457,
#  'governor': 3718,
#  'transpired': 8386,
#  'imagine': 4162,
#  'infiltrated': 4313,
#  'chance': 1523,
#  'hardworking': 3880,
#  'cruz': 2140,
#  'crimea': 2098,
#  'late': 4761,
#  'miserably': 5302,
#  'it': 4527,
#  'hotly': 4071,
#  'spending': 7675,
#  'conversation': 1976,
#  'pardon': 5893,
#  'yoga': 9098,
#  'six': 7509,
#  'clarity': 1634,
#  'values': 8701,
#  'suspends': 8001,
#  'armed': 719,
#  'monsters': 5376,
#  'small': 7544,
#  'honorable': 4034,
#  'worker': 9037,
#  'los': 4976,
#  'beaten': 965,
#  'ball': 886,
#  'contempt': 1935,
#  'tuesday': 8458,
#  'mister': 5325,
#  'pose': 6197,
#  'admiration': 369,
#  'paradigm': 5886,
#  'backseat': 869,
#  'recommendation': 6681,
#  'miriam': 5297,
#  'everything': 3069,
#  'mobility': 5342,
#  'currently': 2162,
#  'personnel': 6028,
#  'proves': 6457,
#  'curriculum': 2163,
#  'fiance': 3324,
#  'religions': 6824,
#  'grateful': 3750,
#  'suffered': 7927,
#  'homophobic': 4026,
#  'vehicle': 8711,
#  'milwaukee': 5269,
#  'generational': 3638,
#  'underground': 8525,
#  'speeches': 7670,
#  'families': 3241,
#  'second': 7267,
#  'jimmy': 4566,
#  'interests': 4422,
#  'indicator': 4286,
#  'witness': 9015,
#  'projections': 6397,
#  'croney': 2118,
#  'tactical': 8046,
#  'discussed': 2561,
#  'upstate': 8651,
#  'expensing': 3143,
#  'memorial': 5200,
#  'damaged': 2187,
#  'facts': 3218,
#  'fronts': 3563,
#  'maximizes': 5148,
#  'purposes': 6500,
#  'spiraling': 7684,
#  'preparation': 6268,
#  'intrigue': 4449,
#  'securing': 7285,
#  'repeating': 6871,
#  'detour': 2441,
#  '258': 127,
#  'decimated': 2243,
#  'say': 7197,
#  'assume': 782,
#  'attribute': 808,
#  'tinkering': 8271,
#  'nothings': 5598,
#  'developed': 2452,
#  'bathed': 946,
#  'congress': 1871,
#  'parade': 5884,
#  'sunday': 7948,
#  'rate': 6606,
#  'planet': 6101,
#  'bomber': 1149,
#  'profligate': 6384,
#  'eventually': 3063,
#  'poorest': 6182,
#  'decreasing': 2259,
#  'suspicious': 8002,
#  'mine': 5275,
#  'genocide': 3645,
#  'situation': 7507,
#  'cartoon': 1440,
#  'playing': 6116,
#  'ransom': 6596,
#  'improve': 4214,
#  'sort': 7623,
#  'facilities': 3209,
#  'import': 4197,
#  'abortions': 255,
#  'bland': 1094,
#  'christianity': 1594,
#  'cpi': 2067,
#  'too': 8296,
#  'nukes': 5615,
#  'davids': 2207,
#  'revenues': 6992,
#  'pandering': 5877,
#  'implode': 4196,
#  'downsize': 2696,
#  'marines': 5109,
#  'propagandist': 6417,
#  'diligence': 2496,
#  'immokalee': 4176,
#  'perseverance': 6021,
#  'need': 5501,
#  'accurate': 304,
#  'phones': 6055,
#  'returning': 6987,
#  'ptsd': 6472,
#  'pinnacle': 6081,
#  'kate': 4639,
#  'eastern': 2777,
#  'altered': 531,
#  'watches': 8879,
#  'flames': 3402,
#  'four': 3523,
#  'voices': 8797,
#  'captured': 1400,
#  'keeps': 4649,
#  'complain': 1792,
#  'hole': 4017,
#  'devalue': 2445,
#  'petulant': 6039,
#  'embarrassed': 2863,
#  'protections': 6447,
#  'machines': 5023,
#  'occupying': 5656,
#  'foothold': 3464,
#  'extending': 3184,
#  'classifying': 1643,
#  'chances': 1524,
#  'compliance': 1802,
#  'tirelessly': 8276,
#  'been': 979,
#  'latino': 4764,
#  'vigilance': 8757,
#  'virtually': 8777,
#  'sphere': 7679,
#  'broadsides': 1251,
#  'connections': 1882,
#  'everytime': 3070,
#  'impacting': 4182,
#  'forced': 3471,
#  'claims': 1629,
#  'chicken': 1569,
#  'militants': 5252,
#  'handout': 3857,
#  'members': 5198,
#  'start': 7746,
#  'happened': 3866,
#  'smiling': 7552,
#  'urging': 8659,
#  'isolated': 4515,
#  'ending': 2933,
#  'secretariat': 7272,
#  'paychecks': 5961,
#  'relative': 6808,
#  'encourage': 2920,
#  'anytime': 632,
#  'predominantly': 6255,
#  'actively': 328,
#  'courses': 2055,
#  'agreement': 455,
#  'include': 4247,
#  'naturalization': 5486,
#  'artificially': 743,
#  'external': 3187,
#  'depravity': 2376,
#  'preys': 6307,
#  'brilliant': 1238,
#  'entirely': 2989,
#  'diminish': 2498,
#  'muslim': 5446,
#  'escalation': 3025,
#  'arrival': 730,
#  'walk': 8834,
#  'stops': 7811,
#  'get': 3656,
#  'uncle': 8514,
#  'staffers': 7722,
#  'sales': 7159,
#  'rally': 6578,
#  'arrested': 728,
#  'warming': 8856,
#  'briefings': 1232,
#  'border': 1167,
#  'part': 5904,
#  'upset': 8647,
#  'proximity': 6469,
#  'portability': 6190,
#  'tuition': 8460,
#  'rebuild': 6654,
#  'owner': 5844,
#  'addressing': 353,
#  'g': 3594,
#  'conducive': 1842,
#  'harder': 3875,
#  'activity': 332,
#  '2nd': 134,
#  'criticized': 2114,
#  'impune': 4218,
#  'airbus': 473,
#  'fomenting': 3455,
#  'responsible': 6948,
#  'israelis': 4520,
#  'minorities': 5285,
#  'explains': 3160,
#  '2004': 99,
#  'taunt': 8093,
#  'laser': 4757,
#  'superstar': 7956,
#  'restored': 6953,
#  '11': 31,
#  'kabul': 4631,
#  'lids': 4879,
#  'kosovo': 4710,
#  'different': 2486,
#  'aggressive': 445,
#  'vendor': 8713,
#  'nine': 5561,
#  'quietly': 6546,
#  'bringing': 1241,
#  'bilateral': 1069,
#  'empathize': 2892,
#  'street': 7836,
#  'commentators': 1745,
#  'waited': 8825,
#  'agrees': 457,
#  'held': 3947,
#  'spender': 7674,
#  'case': 1444,
#  'gosh': 3707,
#  'grows': 3791,
#  'undertaking': 8544,
#  'financial': 3356,
#  'silent': 7478,
#  'advocate': 404,
#  'sympathetic': 8024,
#  'expenditures': 3140,
#  'markets': 5115,
#  'hemisphere': 3956,
#  'disrupt': 2604,
#  'supervision': 7957,
#  'victories': 8747,
#  'straighten': 7818,
#  'rico': 7027,
#  'graduated': 3729,
#  'educating': 2800,
#  'dog': 2658,
#  'exchange': 3096,
#  'crash': 2074,
#  'apologizing': 643,
#  'cheeks': 1560,
#  'refused': 6748,
#  'obstruction': 5646,
#  'overdose': 5816,
#  'men': 5204,
#  'gravity': 3754,
#  'enjoyed': 2966,
#  'nowhere': 5611,
#  'traditions': 8352,
#  'lonnie': 4965,
#  'medical': 5181,
#  'recession': 6668,
#  'overwhelm': 5837,
#  'devastating': 2449,
#  'exploit': 3164,
#  'devastate': 2447,
#  'rightful': 7038,
#  'celebrating': 1480,
#  'shelters': 7400,
#  'exercise': 3116,
#  'fallen': 3236,
#  'elite': 2850,
#  'pesh': 6032,
#  'killer': 4672,
#  'govern': 3713,
#  'theresa': 8201,
#  'welcome': 8927,
#  'horror': 4056,
#  'ounce': 5776,
#  'collecting': 1710,
#  'avenue': 838,
#  'love': 4991,
#  'extremism': 3194,
#  'apprehension': 676,
#  'object': 5635,
#  'precautions': 6244,
#  'actually': 336,
#  'memo': 5199,
#  'data': 2199,
#  'typically': 8490,
#  'tropical': 8430,
#  'korean': 4708,
#  'mechanisms': 5175,
#  'cap': 1388,
#  'offensive': 5669,
#  'abortionists': 254,
#  'several': 7367,
#  '37': 151,
#  'convoluted': 1989,
#  'steal': 7779,
#  'yasser': 9083,
#  'accomplish': 292,
#  'override': 5823,
#  'airmen': 478,
#  'turn': 8471,
#  'difficulty': 2491,
#  'below': 1021,
#  'top': 8300,
#  'beliefs': 1009,
#  'arc': 696,
#  'kamatsu': 4632,
#  'victims': 8746,
#  'announcements': 608,
#  'feels': 3302,
#  'invest': 4461,
#  'outposts': 5792,
#  'significant': 7474,
#  'spent': 7677,
#  'conditioners': 1839,
#  'economics': 2787,
#  '65': 191,
#  'killers': 4673,
#  'blind': 1104,
#  'developments': 2458,
#  'indefinite': 4276,
#  'game': 3605,
#  'blowing': 1119,
#  'lone': 4958,
#  'paranoia': 5890,
#  'special': 7653,
#  'everyday': 3067,
#  'ban': 892,
#  'resting': 6951,
#  'wayand': 8890,
#  'zero': 9113,
#  'equivalent': 3013,
#  'deal': 2215,
#  'passed': 5924,
#  'cybersecurity': 2175,
#  'armies': 720,
#  'egg': 2813,
#  'materiel': 5140,
#  'boot': 1165,
#  'mentally': 5207,
#  'city': 1619,
#  'safeguards': 7145,
#  'chanting': 1531,
#  'thoughtful': 8222,
#  'hassan': 3893,
#  'solar': 7583,
#  'downing': 2695,
#  'ops': 5740,
#  'take': 8051,
#  'johnkasich': 4574,
#  'producer': 6365,
#  'dedicated': 2261,
#  'screwed': 7245,
#  'sewer': 7369,
#  'amtrak': 574,
#  'space': 7642,
#  'encrypted': 2924,
#  'transcript': 8370,
#  'lesser': 4841,
#  'enrollees': 2973,
#  'stewardship': 7791,
#  'agitator': 448,
#  'welcomes': 8929,
#  'viruses': 8780,
#  'easiest': 2773,
#  'pacific': 5852,
#  'complicated': 1803,
#  'voting': 8810,
#  'advocated': 405,
#  'disproportionate': 2596,
#  'unrelated': 8617,
#  'practical': 6230,
#  'likes': 4897,
#  'threat': 8226,
#  'skeptic': 7516,
#  'mitch': 5331,
#  'tester': 8166,
#  'officials': 5680,
#  'historic': 4000,
#  'meaning': 5163,
#  'hanging': 3861,
#  'board': 1126,
#  'direct': 2507,
#  'stuff': 7877,
#  'dismantle': 2584,
#  'pitched': 6088,
#  'regain': 6752,
#  'determining': 2436,
#  'furthermore': 3590,
#  'graduation': 3731,
#  'brings': 1242,
#  'insulting': 4389,
#  'turkish': 8468,
#  'defenses': 2283,
#  'divert': 2631,
#  'copying': 2006,
#  'charleston': 1545,
#  'absentee': 261,
#  'marched': 5098,
#  '16': 47,
#  'racial': 6555,
#  '1981': 82,
#  'blinds': 1107,
#  'snake': 7561,
#  'militaristic': 5254,
#  'characterize': 1537,
#  'crumbling': 2135,
#  'italian': 4528,
#  'favored': 3275,
#  'recovered': 6692,
#  'mention': 5208,
#  'not': 5594,
#  '42': 160,
#  'rammed': 6583,
#  'embassies': 2866,
#  'statistics': 7765,
#  '700': 200,
#  'innovators': 4346,
#  'took': 8297,
#  'losing': 4981,
#  'florists': 3426,
#  'aid': 463,
#  'wait': 8824,
#  'puppet': 6492,
#  'disrupted': 2605,
#  'trillion': 8422,
#  'civics': 1620,
#  'articles': 741,
#  'pointsecond': 6146,
#  'warren': 8863,
#  'cessation': 1502,
#  'looking': 4968,
#  'bombardment': 1146,
#  'broker': 1254,
#  'concur': 1836,
#  'exceptional': 3091,
#  'somewhere': 7611,
#  'priebus': 6313,
#  'payment': 5964,
#  'confirming': 1856,
#  'suits': 7939,
#  'empower': 2904,
#  'inefficiencies': 4301,
#  '2050': 115,
#  'journalists': 4595,
#  'bounty': 1185,
#  'penalty': 5985,
#  'criticizing': 2115,
#  'youngest': 9104,
#  'isil': 4505,
#  'luck': 5006,
#  '15': 45,
#  'canadians': 1377,
#  'leaked': 4798,
#  'sued': 7924,
#  'acquiescing': 316,
#  'human': 4092,
#  'mark': 5110,
#  'manipulation': 5083,
#  'sends': 7317,
#  'yeah': 9085,
#  'revive': 7005,
#  'arbitrary': 695,
#  'scores': 7230,
#  'hearing': 3925,
#  'aft': 428,
#  'rite': 7059,
#  'dorm': 2684,
#  'podium': 6140,
#  'capture': 1399,
#  'discourtesy': 2550,
#  'upgrade': 8638,
#  'jake': 4538,
#  'damn': 2189,
#  'deterred': 2437,
#  'incumbents': 4273,
#  'there': 8199,
#  'properly': 6420,
#  'addict': 343,
#  'hashed': 3892,
#  'a': 231,
#  'describe': 2391,
#  'fans': 3250,
#  'literally': 4921,
#  'pain': 5864,
#  'skepticism': 7518,
#  'ages': 441,
#  "'ought": 13,
#  'talks': 8063,
#  'cultural': 2146,
#  'fads': 3219,
#  'assad': 762,
#  'orderly': 5752,
#  'cozy': 2066,
#  'reasserted': 6649,
#  'older': 5692,
#  'handed': 3852,
#  '130': 42,
#  'multinational': 5431,
#  'walked': 8835,
#  'snowden': 7564,
#  'romney': 7086,
#  'boiling': 1140,
#  'balanced': 882,
#  'stronger': 7859,
#  'differently': 2488,
#  'latinos': 4765,
#  'virginia': 8775,
#  'he': 3908,
#  'embrace': 2873,
#  'nafta': 5460,
#  'skilled': 7520,
#  'caucused': 1463,
#  '30': 136,
#  'thanks': 8181,
#  'outcome': 5782,
#  'neighbors': 5519,
#  'mayors': 5153,
#  '52s': 176,
#  'root': 7093,
#  'assure': 784,
#  'passionately': 5929,
#  'connected': 1878,
#  'tara': 8080,
#  'heartless': 3931,
#  'interplay': 4430,
#  'dark': 2196,
#  'sets': 7357,
#  'fighting': 3335,
#  'reverse': 6995,
#  'poured': 6219,
#  'do': 2647,
#  'testimony': 8170,
#  'governed': 3714,
#  'subsequent': 7893,
#  'fruit': 3564,
#  'subsidize': 7896,
#  'endangering': 2929,
#  'manipulate': 5081,
#  'exxonmobil': 3197,
#  'mail': 5040,
#  'contribute': 1960,
#  'eloquence': 2854,
#  'wolf': 9020,
#  'recipients': 6672,
#  'opponents': 5729,
#  'countrywide': 2047,
#  'affiliated': 415,
#  'cascading': 1443,
#  'dealing': 2217,
#  'memphis': 5203,
#  'appear': 651,
#  'perhaps': 6005,
#  'obliterate': 5641,
#  'chemicals': 1564,
#  'referred': 6726,
#  'incentivize': 4236,
#  'mirror': 5298,
#  'dysfunction': 2757,
#  'staying': 7772,
#  'establish': 3035,
#  'desperate': 2406,
#  'infected': 4310,
#  'lethal': 4848,
#  'prevailed': 6299,
#  'partial': 5905,
#  'expects': 3135,
#  'origin': 5765,
#  'vote': 8805,
#  'inaudible': 4225,
#  'messages': 5223,
#  'hostages': 4063,
#  'wrong': 9070,
#  'listening': 4918,
#  'panama': 5875,
#  'building': 1281,
#  'relying': 6830,
#  'regan': 6754,
#  'temperature': 8132,
#  'el': 2824,
#  'privilege': 6340,
#  'bigots': 1068,
#  'generosity': 3640,
#  'ashamed': 747,
#  'alcoholism': 496,
#  'self': 7305,
#  'knock': 4696,
#  'our': 5777,
#  'broadly': 1250,
#  'precious': 6247,
#  'time': 8264,
#  'mitigate': 5333,
#  'turnouts': 8475,
#  'communities': 1770,
#  'stand': 7734,
#  'environment': 2998,
#  'vets': 8733,
#  'imprisoning': 4213,
#  '97': 225,
#  'intensity': 4406,
#  'cdc': 1474,
#  'engagements': 2955,
#  'valley': 8697,
#  'nikki': 5559,
#  'liquid': 4913,
#  'cleanup': 1651,
#  'policies': 6157,
#  'ourselves': 5779,
#  'managed': 5066,
#  '1960s': 71,
#  'enemies': 2943,
#  'conservatives': 1896,
#  'unanswered': 8506,
#  'credit': 2094,
#  'fairness': 3231,
#  'wedge': 8917,
#  'tallahassee': 8065,
#  'telemundo': 8125,
#  'bluster': 1125,
#  'specifying': 7662,
#  'throats': 8241,
#  'jobs': 4570,
#  'files': 3343,
#  'differential': 2487,
#  'along': 525,
#  'belongs': 1019,
#  'fantastic': 3252,
#  'sponsored': 7696,
#  'prayed': 6239,
#  'entails': 2977,
#  'conducting': 1845,
#  'distributed': 2620,
#  'barbaric': 914,
#  'martinomalley': 5123,
#  'lashing': 4758,
#  'pretenses': 6297,
#  'am': 542,
#  'embed': 2868,
#  'outraged': 5795,
#  'lucky': 5008,
#  'restructure': 6959,
#  'letting': 4852,
#  'streamlined': 7835,
#  'black': 1089,
#  'through': 8242,
#  'enter': 2979,
#  'esp': 3028,
#  'sarah': 7178,
#  '150': 46,
#  'continuum': 1952,
#  'credits': 2095,
#  'bankrupted': 901,
#  'restructuring': 6960,
#  'legacy': 4816,
#  'regard': 6755,
#  'courage': 2052,
#  '1990s': 88,
#  'james': 4539,
#  'about': 256,
#  'secretary': 7274,
#  'swamp': 8006,
#  'meantime': 5168,
#  'wing': 8989,
#  '2009': 104,
#  'frederick': 3542,
#  'basket': 942,
#  'province': 6465,
#  'birth': 1080,
#  'reforming': 6738,
#  'demographics': 2335,
#  'marrying': 5118,
#  'redundant': 6715,
#  'topline': 8304,
#  'african': 427,
#  'zones': 9119,
#  'areall': 705,
#  'sick': 7459,
#  '11th': 36,
#  'potential': 6215,
#  "o'donnell": 5627,
#  'disputed': 2600,
#  'abuser': 271,
#  'bank': 895,
#  'immediate': 4168,
#  'delay': 2307,
#  'wit': 9007,
#  'bet': 1043,
#  'evolution': 3076,
#  'quarantined': 6531,
#  'insecure': 4352,
#  'rove': 7110,
#  'state': 7755,
#  'security': 7286,
#  'leader': 4792,
#  'heal': 3916,
#  'implemented': 4192,
#  'warplanes': 8860,
#  'meanwhile': 5169,
#  '90s': 220,
#  'successfully': 7913,
#  'fire': 3372,
#  'iranian': 4492,
#  'should': 7436,
#  'terribly': 8154,
#  'restoring': 6954,
#  'invade': 4454,
#  'laughing': 4769,
#  'apologizes': 642,
#  'cooney': 1992,
#  'byron': 1339,
#  'decorations': 2256,
#  'developing': 2454,
#  'pointing': 6144,
#  'phase': 6044,
#  'judicial': 4608,
#  'backs': 868,
#  'deciding': 2240,
#  'furlough': 3588,
#  'conform': 1861,
#  'annie': 603,
#  'gather': 3622,
#  'tackle': 8042,
#  'life': 4883,
#  'slogans': 7540,
#  'dedicates': 2262,
#  'aliens': 501,
#  'revealed': 6990,
#  'honored': 4036,
#  'pushing': 6506,
#  'agonizing': 450,
#  'demonstrates': 2341,
#  'visceral': 8783,
#  'terrorism': 8159,
#  'reserve': 6911,
#  'move': 5413,
#  'foster': 3516,
#  'slot': 7541,
#  'religious': 6825,
#  'dislodge': 2583,
#  'hell': 3948,
#  'paraphrasing': 5892,
#  'retroactively': 6984,
#  'information': 4324,
#  'majority': 5051,
#  'resigned': 6920,
#  'petitioned': 6035,
#  'osama': 5771,
#  'equipment': 3010,
#  'murdered': 5437,
#  'hug': 4087,
#  'atomic': 792,
#  'population': 6187,
#  'millionaire': 5265,
#  'where': 8949,
#  'healed': 3917,
#  'extend': 3182,
#  'choices': 1584,
#  'dealings': 2218,
#  'democracy': 2330,
#  'modernize': 5354,
#  'unsustainable': 8625,
#  'bench': 1025,
#  'thrive': 8237,
#  'player': 6114,
#  'incredible': 4267,
#  'reward': 7011,
#  'touching': 8319,
#  'manipulating': 5082,
#  'portend': 6192,
#  'crop': 2122,
#  'stabilize': 7713,
#  'sentiments': 7330,
#  'detonate': 2440,
#  'gains': 3599,
#  'guards': 3800,
#  'rides': 7031,
#  'trades': 8347,
#  'levers': 4858,
#  'antidote': 619,
#  'forgive': 3490,
#  'outlined': 5789,
#  'terrorists': 8161,
#  'altar': 530,
#  'heartly': 3933,
#  'reconciliation': 6685,
#  'marathon': 5096,
#  'las': 4756,
#  '2008': 103,
#  'fencing': 3313,
#  'waving': 8888,
#  'bid': 1059,
#  'parents': 5900,
#  'truancy': 8435,
#  'possibility': 6207,
#  'disability': 2516,
#  'grassroots': 3749,
#  'honor': 4033,
#  'biden': 1062,
#  'ame': 554,
#  'hung': 4105,
#  'predictable': 6254,
#  'suffering': 7928,
#  'leftist': 4814,
#  'launch': 4772,
#  'trail': 8359,
#  'proceeds': 6357,
#  'name': 5465,
#  'demonstrate': 2339,
#  'susan': 7995,
#  'kerry': 4657,
#  'dealers': 2216,
#  'praising': 6237,
#  'favorably': 3274,
#  'tradition': 8349,
#  'townhalls': 8334,
#  'releases': 6817,
#  'feckless': 3291,
#  'ceos': 1495,
#  'weakened': 8895,
#  'victim': 8744,
#  'many': 5092,
#  'rating': 6609,
#  'brigades': 1234,
#  'finally': 3353,
#  'bangladesh': 894,
#  'pledge': 6123,
#  'defrauding': 2297,
#  'customers': 2167,
#  'guns': 3817,
#  'flag': 3400,
#  'thrice': 8235,
#  'additional': 350,
#  'joe': 4571,
#  'delegates': 2309,
#  'raise': 6573,
#  'substantive': 7902,
#  'drag': 2708,
#  'cancel': 1379,
#  'horrified': 4054,
#  'marine': 5108,
#  'centered': 1488,
#  'departments': 2359,
#  'amazingly': 547,
#  'embassy': 2867,
#  'weaknesses': 8900,
#  'shortcut': 7431,
#  'charlie': 1546,
#  'earning': 2767,
#  'relation': 6804,
#  'opposed': 5733,
#  'videotape': 8751,
#  'm': 5019,
#  'groundwork': 3785,
#  'excruciating': 3103,
#  'refers': 6728,
#  'interfere': 4424,
#  'meaningless': 5165,
#  'disagreement': 2524,
#  'darn': 2197,
#  '20th': 117,
#  'thatcher': 8183,
#  'edward': 2803,
#  'pristine': 6332,
#  'doorstep': 2682,
#  'mailed': 5041,
#  'deere': 2272,
#  'talent': 8055,
#  'forth': 3505,
#  'joining': 4579,
#  'rescued': 6909,
#  'worried': 9045,
#  'spin': 7682,
#  'except': 3089,
#  'cheat': 1554,
#  'battleground': 954,
#  'next': 5545,
#  'florida': 3425,
#  'bloated': 1109,
#  'led': 4811,
#  'oppose': 5732,
#  'threshold': 8233,
#  'window': 8988,
#  'shape': 7384,
#  'testified': 8167,
#  'responders': 6941,
#  'struggling': 7869,
#  'unbelievable': 8510,
#  'decorated': 2255,
#  'painful': 5865,
#  'crowds': 2133,
#  'behalf': 993,
#  'registered': 6764,
#  'recklessness': 6675,
#  'reciprocal': 6673,
#  'expenditure': 3139,
#  'homeland': 4020,
#  ...}

# %%
nb_clf = MultinomialNB().fit(X_train_dtm, train_df.speaker)

# %%
X_test_dtm = vect.transform(test_df.sentence)
predicted_speaker=nb_clf.predict(X_test_dtm)

# %%
metrics.accuracy_score(test_df.speaker, predicted_speaker)
# Out:
# 0.3475

# %%
print(metrics.classification_report(test_df.speaker, predicted_speaker, target_names=test_df.speaker.unique()))
# Out:
#               precision    recall  f1-score   support
#
#      sanders       0.00      0.00      0.00        30
#      clinton       0.00      0.00      0.00        16
#     o'malley       0.00      0.00      0.00         2
#       chafee       0.00      0.00      0.00        12
#         webb       0.38      0.53      0.44        53
#     huckabee       0.00      0.00      0.00        34
#        trump       0.00      0.00      0.00        10
#         cruz       0.00      0.00      0.00         7
#         paul       0.00      0.00      0.00        31
#     christie       0.00      0.00      0.00        18
#        rubio       0.00      0.00      0.00         5
#      fiorina       0.00      0.00      0.00        41
#       kasich       0.46      0.66      0.54        64
#         bush       0.29      0.97      0.45        71
#       carson       0.00      0.00      0.00         3
#       walker       0.00      0.00      0.00         3
#
#     accuracy                           0.35       400
#    macro avg       0.07      0.13      0.09       400
# weighted avg       0.18      0.35      0.23       400
# c:\users\mohammed\appdata\local\programs\python\python35\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# TFIDF feature tries to find out unique word by considering how frequent a word occurs in document and how rare it is in other document. Since the data set does not contain any such things, the accuracy decreases to 36% when tfidf feature is used
